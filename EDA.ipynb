# %%
import pandas as pd
import json
import numpy
import os
import glob
import csv
import seaborn as sns

# %%
folder = '글짓기'
folder2 = '대안제시'
folder3 = '설명글'
folder4 = '주장'
folder5 = '찬성반대'

# %%
path = f'./clear/{folder}/{folder}_rubric.csv'
path2 = f'./clear/{folder2}/{folder2}_rubric.csv'
path3 = f'./clear/{folder3}/{folder3}_rubric.csv'
path4 = f'./clear/{folder4}/{folder4}_rubric.csv'
path5 = f'./clear/{folder5}/{folder5}_rubric.csv'

# file_list = os.listdir(path)
# file_list_py = [file for file in file_list if file.endswith('.json')] ## 파일명 끝이 .csv인 경우

# %%
df = pd.read_csv(path, sep=",")
df2 = pd.read_csv(path2, sep=",")
df3 = pd.read_csv(path3, sep=",")
df4 = pd.read_csv(path4, sep=",")
df5 = pd.read_csv(path5, sep=",")

# %%
df = pd.concat([df, df2, df3, df4, df5], ignore_index = True)

# %%
df
# Out:
#       org_paragraph  org  org_essay  org_coherence  org_quantity essay_type  \
# 0                 5    2          1              1             1        글짓기
# 1                 3    2          3              2             1        글짓기
# 2                 5    2          1              1             1        글짓기
# 3                 3    2          3              2             1        설명글
# 4                 3    2          3              2             1        글짓기
# ...             ...  ...        ...            ...           ...        ...
# 5995              3    3          0              0             1       찬성반대
# 5996              7    3          0              2             1       찬성반대
# 5997              3    3          3              3             1       찬성반대
# 5998              7    3          0              2             1       찬성반대
# 5999              6    3          0              3             1       찬성반대
#
# ...

# %%
df.grouby('')
# Out:
# <bound method DataFrame.groupby of       org_paragraph  org  org_essay  org_coherence  org_quantity essay_type  \
# 0                 5    2          1              1             1        글짓기
# 1                 3    2          3              2             1        글짓기
# 2                 5    2          1              1             1        글짓기
# 3                 3    2          3              2             1        설명글
# 4                 3    2          3              2             1        글짓기
# ...             ...  ...        ...            ...           ...        ...
# 5995              3    3          0              0             1       찬성반대
# 5996              7    3          0              2             1       찬성반대
# 5997              3    3          3              3             1       찬성반대
# 5998              7    3          0              2             1       찬성반대
# 5999              6    3          0              3             1       찬성반대
#
# ...

# %%
essay_grade = []

org_paragraph = []
org = []
org_essay = []
org_coherence = []
org_quantity= []

essay_type = []

con_novelty = []
con_clearance = []
con = []
con_prompt = []
con_description = []

essay_main_subject = []

exp_style = []
exp_grammar = []
exp = []
exp_vocab = []

for p in dict_list:
    rubric = p['rubric']
    essay_grade.append(rubric['essay_grade'])

    org_paragraph.append(rubric['organization_weight']['org_paragraph'])
    org.append(rubric['organization_weight']['org'])
    org_essay.append(rubric['organization_weight']['org_essay'])
    org_coherence.append(rubric['organization_weight']['org_coherence'])
    org_quantity.append(rubric['organization_weight']['org_quantity'])

    essay_type.append(rubric['essay_type'])
    
    con_novelty.append(rubric['content_weight']['con_novelty'])
    con_clearance.append(rubric['content_weight']['con_clearance'])
    con.append(rubric['content_weight']['con'])
    con_prompt.append(rubric['content_weight']['con_prompt'])
    con_description.append(rubric['content_weight']['con_description'])

    exp_style.append(rubric['expression_weight']['exp_style'])
    exp_grammar.append(rubric['expression_weight']['exp_grammar'])
    exp.append(rubric['expression_weight']['exp'])
    exp_vocab.append(rubric['expression_weight']['exp_vocab'])

rubric_dict = {
    'paragraph_scoreT': paragraph_scoreT,
    'paragraph_scoreT_exp': paragraph_scoreT_exp,
    'paragraph_scoreT_avg': paragraph_scoreT_avg,
    'paragraph_id': paragraph_id,
}

rubric_df = pd.DataFrame(rubric_dict)

# %%
rubric_df.to_csv(f'./clear/{folder}/{folder}_rubric.csv')

# %%
dict_list[0]['student']
# Out:
# {'date': '2021.11.29',
#  'student_educated': True,
#  'student_grade': '중등_3학년',
#  'student_school': '영주중학교',
#  'location': '054',
#  'student_grade_group': '중등',
#  'student_reading': 3}

# %%
date = []
student_educated = []
student_grade = []
student_school = []
location = []
student_grade_group = []
student_reading = []

for p in dict_list:
    student = p['student']
    date.append(student['date'])

    student_educated.append(student['student_educated'])
    student_grade.append(student['student_grade'])
    student_school.append(student['student_school'])
    location.append(student['location'])
    student_grade_group.append(student['student_grade_group'])
    student_reading.append(student['student_reading'])

student_dict = {
    'student_educated': student_educated,
    'student_grade': student_grade,
    'student_school': student_school,
    'location': location,
    'student_grade_group': student_grade_group,
    'student_reading': student_reading,
}

student_df = pd.DataFrame(student_dict)

# %%
student_df.to_csv(f'./clear/{folder}/{folder}_student.csv')

# %%
dict_list[0]['correction']
# Out:
# {'sentence_corr_txt_grammar': '',
#  'sentence_corr_reason': [],
#  'sentence_id': '',
#  'sentence_annotation_tag': '',
#  'sentence_corr_type': [],
#  'sentence_corr_detail_type': [],
#  'sentence_txt': '',
#  'sentence_corr_txt_styling': '',
#  'paragraph_id': ''}

# %%
# sentence_corr_txt_grammar = []
# sentence_corr_reason = []
# sentence_id = []
# sentence_annotation_tag = []
# sentence_corr_type = []
# sentence_corr_detail_type = []
# sentence_txt = []
# sentence_corr_txt_styling = []
# paragraph_id = []

# for p in dict_list:
#     correction = p['correction']
#     print(correction)
#     sentence_corr_txt_grammar.append(correction['sentence_corr_txt_grammar'])
#     sentence_corr_reason.append(correction['sentence_corr_reason'])
#     sentence_id.append(correction['sentence_id'])
#     sentence_annotation_tag.append(correction['sentence_annotation_tag'])
#     sentence_corr_type.append(correction['sentence_corr_type'])
#     sentence_corr_detail_type.append(correction['sentence_corr_detail_type'])
#     sentence_txt.append(correction['sentence_txt'])
#     sentence_corr_txt_styling.append(correction['sentence_corr_txt_styling'])
#     paragraph_id.append(correction['paragraph_id'])

# correction_dict = {
#     'sentence_corr_txt_grammar': sentence_corr_txt_grammar,
#     'sentence_corr_reason': sentence_corr_reason,
#     'sentence_id': sentence_id,
#     'sentence_annotation_tag': sentence_annotation_tag,
#     'sentence_corr_type': sentence_corr_type,
#     'sentence_corr_detail_type': sentence_corr_detail_type,
#     'sentence_txt': sentence_txt,
#     'sentence_corr_txt_styling': sentence_corr_txt_styling,
#     'paragraph_id': paragraph_id,
# }

# correction_df = pd.DataFrame(correction_dict)

# %%
# correction_df.to_csv(f'./clear/{folder}/{folder}_correction.csv')

# %%
dict_list[0]['info']
# Out:
# {'essay_id': 'ESSAY_54245',
#  'essay_prompt': " 전통은 역사적으로 건전하게 전승된 물질문화, 사고와 행위 양식, 사람이나 사건에 대한 인상, 갖가지 상징군(象徵群)으로 과거로부터 이어져 온 것 중에 오늘날에 지킬 만한 좋은 풍습을 놓고 '전통'이라 합니다.\n\n 반대로 '악습'은 '나쁜 풍습'을 일컫는 말로, 대개 현대의 인권 의식을 바탕으로 용납할 수 없는 풍습을 말합니다.\n\n 나라마다 문화도 다르니 전해져 내려오는 풍습도 다르겠죠?\n\n 우리나라에서도 예전부터 지켜오던 풍습들이 존재할 겁니다. 이를 태면 설/추석에 제사를 지내거나 복날에 삼계탕을 먹는다든가 하는 풍습들이 존재하지요.\n\n 하지만 분명히 우리나라의 풍습에도 전통이 있고 악습이 있을 것 같아요.\n\n 여러분이 생각하는 우리의 전통과 악습 한 가지씩을 작성해보세요. 그리고 그렇게 생각하는 이유에 대해서도 말해보아요. 아주 오래전에 있던 풍습이 아니어도 되고 은연중에 생겨난 우리나라의 풍습을 적어보아도 좋아요.",
#  'essay_type': '주장',
#  'essay_level': '2',
#  'essay_len': 1055,
#  'essay_main_subject': '전통과 악습에 대한 본인 생각을 작성'}

# %%
essay_id = []
essay_prompt = []
essay_type = []
essay_level = []
essay_len = []
essay_main_subject = []

for p in dict_list:
    info = p['info']
    essay_id.append(info['essay_id'])
    essay_prompt.append(info['essay_prompt'])
    essay_type.append(info['essay_type'])
    essay_level.append(info['essay_level'])
    essay_len.append(info['essay_len'])
    essay_main_subject.append(info['essay_main_subject'])


info_dict = {
    'essay_id': essay_id,
    'essay_prompt': essay_prompt,
    'essay_type': essay_type,
    'essay_level': essay_level,
    'essay_len': essay_len,
    'essay_main_subject': essay_main_subject,
}

info_df = pd.DataFrame(info_dict)

# %%
info_df.to_csv(f'./clear/{folder}/{folder}_info.csv')
